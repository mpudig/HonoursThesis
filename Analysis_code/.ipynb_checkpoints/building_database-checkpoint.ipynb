# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=4)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:43593' processes=4 threads=4, memory=16.00 GiB>

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'
session = cc.database.create_session(db)
cc.querying.get_experiments(session, all=True)
# Out:
#                              experiment contact email created description  \
# 0                   1deg_jra55_ryf_cont    None  None    None        None
# 1    1deg_jra55_ryf_sinusoid_x1_period2    None  None    None        None
# 2    1deg_jra55_ryf_sinusoid_x1_period5    None  None    None        None
# 3   1deg_jra55_ryf_sinusoid_x1_period20    None  None    None        None
# 4   1deg_jra55_ryf_sinusoid_x1_period10    None  None    None        None
# 5    1deg_jra55_ryf_sinusoid_x1_period7    None  None    None        None
# 6   1deg_jra55_ryf_sinusoid_x1_period12    None  None    None        None
# 7   1deg_jra55_ryf_sinusoid_x1_period16    None  None    None        None
# 8              1deg_jra55_ryf_cont_nokb    None  None    None        None
# 9               1deg_jra55_ryf_cont_kb4    None  None    None        None
# 10               1deg_jra55_ryf_cool_x1    None  None    None        None
# 11               1deg_jra55_ryf_cool_x2    None  None    None        None
# 12           1deg_jra55_ryf_cool_x1_kb4    None  None    None        None
# 13          1deg_jra55_ryf_cool_x1_nokb    None  None    None        None
# 14               1deg_jra55_ryf_warm_x1    None  None    None        None
# 15               1deg_jra55_ryf_warm_x2    None  None    None        None
#
#    notes   url                                           root_dir  ncfiles
# 0   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...    15984
# 1   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 2   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 3   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 4   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 5   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 6   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 7   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 8   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     7906
# 9   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     7906
# 10  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     3820
# 11  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4010
# 12  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
# 13  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
# 14  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4010
# 15  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     3820

# %%
help(cc.database.build_index)
# Out:
# Help on function build_index in module cosima_cookbook.database:
#
# build_index(directories, session, client=None, prune='delete', force=False, followsymlinks=False)
#     Index all netcdf files contained within experiment directories.
#
#     Requires a session for the database that's been created with the
#     create_session() function. If client is not None, use a distributed
#     client for processing files in parallel. If prune is set to 'flag' files
#     that are already in the database but are missing from the filesystem will
#     be flagged as missing, or if set to 'delete' they will be removed from the
#     database. If force is False only files that are not in the database will
#     be indexed, othewise if True all files will be indexed and their database
#     entries updated. Symbolically linked files and/or directories will be
#     indexed if followsymlinks is True.
#
#     Returns the number of new files that were indexed.

# %%
# directories = cc.querying.get_experiments(session, all=True)['root_dir'].to_list()

cc.database.build_index(directories, session)
cc.querying.get_experiments(session, all=True)
# Out:
# Indexing experiment: 1deg_jra55_ryf_warm_x1_kb4
# 100%|██████████| 514/514 [00:13<00:00, 38.30it/s]
# Indexing experiment: 1deg_jra55_ryf_warm_x1_nokb
# 100%|██████████| 514/514 [00:54<00:00,  9.36it/s]
#                              experiment contact email created description  \
# 0                   1deg_jra55_ryf_cont    None  None    None        None
# 1    1deg_jra55_ryf_sinusoid_x1_period2    None  None    None        None
# 2    1deg_jra55_ryf_sinusoid_x1_period5    None  None    None        None
# 3   1deg_jra55_ryf_sinusoid_x1_period20    None  None    None        None
# 4   1deg_jra55_ryf_sinusoid_x1_period10    None  None    None        None
# 5    1deg_jra55_ryf_sinusoid_x1_period7    None  None    None        None
# 6   1deg_jra55_ryf_sinusoid_x1_period12    None  None    None        None
# 7   1deg_jra55_ryf_sinusoid_x1_period16    None  None    None        None
# 8              1deg_jra55_ryf_cont_nokb    None  None    None        None
# 9               1deg_jra55_ryf_cont_kb4    None  None    None        None
# 10               1deg_jra55_ryf_cool_x1    None  None    None        None
# 11               1deg_jra55_ryf_cool_x2    None  None    None        None
# 12           1deg_jra55_ryf_cool_x1_kb4    None  None    None        None
# 13          1deg_jra55_ryf_cool_x1_nokb    None  None    None        None
# 14               1deg_jra55_ryf_warm_x1    None  None    None        None
# 15               1deg_jra55_ryf_warm_x2    None  None    None        None
# 16           1deg_jra55_ryf_warm_x1_kb4    None  None    None        None
# 17          1deg_jra55_ryf_warm_x1_nokb    None  None    None        None
#
#    notes   url                                           root_dir  ncfiles
# 0   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...    15984
# 1   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 2   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 3   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 4   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4626
# 5   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 6   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 7   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     2626
# 8   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     7906
# 9   None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     7906
# 10  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     3820
# 11  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4010
# 12  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
# 13  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
# 14  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     4010
# 15  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...     3820
# 16  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
# 17  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...      514
