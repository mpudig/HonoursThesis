# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit
from xhistogram.xarray import histogram

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=4)
display(client)
# Out:
# 2022-03-28 10:38:21,319 - distributed.diskutils - INFO - Found stale lock file and directory '/jobfs/37359771.gadi-pbs/dask-worker-space/worker-6t52lvjh', purging
# 2022-03-28 10:38:21,320 - distributed.diskutils - INFO - Found stale lock file and directory '/jobfs/37359771.gadi-pbs/dask-worker-space/worker-c54hqkdv', purging
# 2022-03-28 10:38:21,320 - distributed.diskutils - INFO - Found stale lock file and directory '/jobfs/37359771.gadi-pbs/dask-worker-space/worker-mtckmzf7', purging
# 2022-03-28 10:38:21,320 - distributed.diskutils - INFO - Found stale lock file and directory '/jobfs/37359771.gadi-pbs/dask-worker-space/worker-dvotlcmn', purging
# <Client: 'tcp://127.0.0.1:41315' processes=4 threads=8, memory=60.00 GiB>

# %%
# # ### Generate new database

# db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'
# session = cc.database.create_session(db)
# # cc.querying.get_experiments(session, all=True)

# pd.set_option('display.max_rows', None)
# cc.querying.get_variables(session, '1deg_jra55_ryf_cont')

# %%
yr_beg = '2400-01-01'
yr_end = '2410-12-31'

strat_cont = xr.open_mfdataset(paths='/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_cont/output1*/ocean/ocean-3d-pot_rho_2*', 
                             combine='by_coords').pot_rho_2.sel(time=slice(yr_beg, yr_end)).mean(dim='time').load()
strat_cool = xr.open_mfdataset(paths='/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_cool_x1/output1*/ocean/ocean-3d-pot_rho_2*', 
                             combine='by_coords').pot_rho_2.sel(time=slice(yr_beg, yr_end)).mean(dim='time').load()
strat_warm = xr.open_mfdataset(paths='/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_warm_x1/output1*/ocean/ocean-3d-pot_rho_2*', 
                             combine='by_coords').pot_rho_2.sel(time=slice(yr_beg, yr_end)).mean(dim='time').load()

# area_t = cc.querying.getvar('1deg_jra55_ryf_cont', 'area_t', session, n=1).load()

# # Area-weighted average

# strat_cont = (area_t * strat_cont) / area_t.sum(dim=('xt_ocean', 'yt_ocean'))
# strat_cool = (area_t * strat_cool) / area_t.sum(dim=('xt_ocean', 'yt_ocean'))
# strat_warm = (area_t * strat_warm) / area_t.sum(dim=('xt_ocean', 'yt_ocean'))

# %%
test = xr.open_mfdataset(paths='/g/data/ik11/outputs/access-om2-025/025deg_jra55_ryf9091_gadi/output324/ocean/ocean.nc', 
                             combine='by_coords').pot_rho_0.sel(time=slice('2549-01-01', '2549-12-31')).mean(dim='time')#.load()

# %%
test1 = xr.open_mfdataset(paths='/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_cont/output100/ocean/ocean-3d-pot_rho_2*', 
                             combine='by_coords').pot_rho_2.mean(dim='time')

# %%
((test1 * area_t).sum(dim=('xt_ocean', 'yt_ocean')) / area_t.sum(dim=('xt_ocean', 'yt_ocean'))).load()
# Out:
# <xarray.DataArray (st_ocean: 50)>
# array([788.7751 , 788.7786 , 788.784  , 788.79474, 785.5372 , 783.3841 ,
#        781.2028 , 778.45294, 775.1403 , 771.3881 , 768.0049 , 763.80817,
#        760.07355, 756.40393, 752.5156 , 749.68243, 746.79474, 743.4646 ,
#        740.48096, 737.3337 , 733.80707, 730.3331 , 726.8514 , 723.0725 ,
#        718.8975 , 715.2792 , 711.57043, 708.0243 , 704.0099 , 699.83   ,
#        694.4628 , 689.1909 , 682.5545 , 674.8736 , 666.6913 , 658.0135 ,
#        646.6745 , 634.7952 , 618.55945, 596.79834, 568.492  , 532.4279 ,
#        489.6093 , 440.97083, 387.96844, 331.2167 , 271.67352, 217.20815,
#        163.16237, 106.9697 ], dtype=float32)
# Coordinates:
#   * st_ocean  (st_ocean) float64 1.152 3.649 6.565 ... 5.034e+03 5.254e+03

# %%
plt.figure(figsize=(7,11))

depth = 1200

strat_cont.mean(dim=('xt_ocean', 'yt_ocean')).sel(st_ocean=slice(None,depth)).plot(yincrease=False, label='control', color='k')
strat_cool.mean(dim=('xt_ocean', 'yt_ocean')).sel(st_ocean=slice(None,depth)).plot(yincrease=False, label='cool', color='b')
strat_warm.mean(dim=('xt_ocean', 'yt_ocean')).sel(st_ocean=slice(None,depth)).plot(yincrease=False, label='warm', color='r')
fontsize=12
plt.grid()
plt.legend(fontsize=fontsize)

# %%
plt.figure(figsize=(7,11))

depth = 1200

(-1*(strat_cool - strat_cont)).mean(dim=('xt_ocean', 'yt_ocean')).sel(st_ocean=slice(None,depth)).plot(yincrease=False, label=r'cool $\times -1$', color='b')
(strat_warm - strat_cont).mean(dim=('xt_ocean', 'yt_ocean')).sel(st_ocean=slice(None,depth)).plot(yincrease=False, label='warm', color='r')

fontsize=12
plt.grid()
plt.legend(fontsize=fontsize)

# %%
###

# %%
strat_cont_01 = xr.open_mfdataset(paths='/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091/output99*/ocean/ocean.nc', 
                             combine='by_coords').pot_rho_0.sel(time=slice('2150-01-01', '2150-12-31')).mean(dim='time').mean(dim=('xt_ocean', 'yt_ocean')).load()
# Out:
# 2022-03-28 11:40:26,329 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 10.53 GiB -- Worker memory limit: 15.00 GiB
# 2022-03-28 11:40:26,348 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 10.54 GiB -- Worker memory limit: 15.00 GiB
# 2022-03-28 11:40:26,430 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 10.56 GiB -- Worker memory limit: 15.00 GiB
# ...

# %%
strat_cont_025 = xr.open_mfdataset(paths='/g/data/ik11/outputs/access-om2-025/025deg_jra55_ryf9091_gadi/output324/ocean/ocean.nc', 
                             combine='by_coords').pot_rho_0.sel(time=slice('2549-01-01', '2549-12-31')).mean(dim='time').mean(dim=('xt_ocean', 'yt_ocean')).load()

# %%
plt.figure(figsize=(7,11))

depth = 2000

strat_cont_01.sel(st_ocean=slice(None,depth)).plot(yincrease=False, label=r'01 deg', color='C0')
strat_cont_025.sel(st_ocean=slice(None,depth)).plot(yincrease=False, label='025 deg', color='C1')

fontsize=12
plt.grid()
plt.legend(fontsize=fontsize)
