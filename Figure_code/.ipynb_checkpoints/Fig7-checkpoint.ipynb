# %% [markdown]
# Following similar code from https://github.com/COSIMA/ACCESS-OM2-1-025-010deg-report/blob/master/figures/overturning_circulation/GlobalOverturningStreamfunction.ipynb...

# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit
from xhistogram.xarray import histogram
from collections import OrderedDict

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=8)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:33047' processes=8 threads=8, memory=120.00 GiB>

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'

session = cc.database.create_session(db)

# %%
exptdict = OrderedDict([
    ('warm',  {'expt': '1deg_jra55_ryf_warm_x1'}),
    ('control',  {'expt': '1deg_jra55_ryf_cont'}),
    ('cool',  {'expt': '1deg_jra55_ryf_cool_x1'})])

# %%
keys = ['warm', 'control', 'cool']
colors = {'warm': 'r','control': 'k','cool':'b'}
linestyles = {'warm': '-','control': '-','cool':'-'}
yr_beg = '2400-01-01'
yr_end = '2499-12-31'

amocs = []
plt.figure(figsize=(14, 7))

for ekey in exptdict:
    expt = exptdict[ekey]['expt']
    
    ### Calculate AMOC from maximum of rho-lat streamfunction ###
    
    var = xr.open_mfdataset(paths=f'/scratch/e14/mp2135/access-om2/archive/{expt}/output1*/ocean/ocean-3d-ty_trans_rho-1-monthly-mean-ym*', \
                            combine='by_coords').ty_trans_rho.sel(time=slice(yr_beg, yr_end))
    
    # convert from kg m**-1 to Sv
    rho = 1025 # mean density of sea-water in kg/m^3
    psi_amoc = var.sel(grid_xt_ocean = slice(- 103, - 5)).sum('grid_xt_ocean').sel(method = 'Nearest', grid_yu_ocean = 26) / (1e6 * rho)
    psi_amoc_sum = psi_amoc.cumsum('potrho') - psi_amoc.sum('potrho')
    
    try:
        var2 = xr.open_mfdataset(paths=f'/scratch/e14/mp2135/access-om2/archive/{expt}/output1*/ocean/ocean-3d-ty_trans_rho_gm-1-monthly-mean-ym*', \
                                 combine='by_coords').ty_trans_rho_gm.sel(time=slice(yr_beg, yr_end))
        
        psi_amoc_gm = var2.sel(grid_xt_ocean = slice( - 103, - 5)).sum('grid_xt_ocean').sel(method = 'Nearest', grid_yu_ocean = 26) / (1e6 * rho)
        # Note that in MOM5 the ty_trans_rho_GM variable is 
        # computed differently and does not require summing in the vertical
        # as we did with psi_amoc_sum.
        
    except:
        print('GM term not found')
        
    psi_amoc_sum = (psi_amoc_sum + psi_amoc_gm).sel(potrho = slice(1035.5, None)).max('potrho').resample(time = 'Y').mean().dropna('time').load()    
    
    ### Plot ###
    amocs.append(psi_amoc_sum)
    plt.plot(np.linspace(0,100,psi_amoc_sum.time.shape[0]), psi_amoc_sum, label = ekey, color = colors[ekey], linestyle = linestyles[ekey])

fontsize = 18
xlims = plt.xlim()
plt.xlabel('Years', fontsize=fontsize)
plt.ylabel('Overturning (Sv)', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend(fontsize=fontsize)
plt.title('AMOC overturning strength', fontsize=fontsize+4)
plt.grid()
# plt.savefig('Fig7.pdf', bbox_inches='tight', dpi=300)
