# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=8)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:41273' processes=8 threads=8, memory=128.85 GB>

# %%
help(cc.database.build_index)
# Out:
# Help on function build_index in module cosima_cookbook.database:
#
# build_index(directories, session, client=None, update=False, prune=True, delete=True, followsymlinks=False)
#     Index all netcdf files contained within experiment directories.
#
#     Requires a session for the database that's been created with the create_session() function.
#     If client is not None, use a distributed client for processing files in parallel.
#     May scan for only new entries to add to database with the update flag.
#     If prune is True files that are already in the database but are missing from the filesystem
#     will be either removed if delete is also True, or flagged as missing if delete is False.
#     Symbolically linked files and/or directories will be indexed if followsymlinks is True.
#
#     Returns the number of new files that were indexed.

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'

session = cc.database.create_session(db)

# directories = ['/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPwarm_humid_x1',
#               '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPwarm_humid_x2',
#               '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x1',
#               '/g/data/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x2']

cc.database.build_index('/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_cont', session, update=True)
# Out:
# Indexing experiment: 1deg_jra55_ryf_cont
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 23% CPU time recently (threshold: 10%)
# ...
# 100%|██████████| 19084/19084 [25:51<00:00, 12.30it/s]
# 19084

# %%
cc.querying.get_experiments(session, all=True)
# Out:
#                                     experiment contact email created  \
# 0                          1deg_jra55_ryf_cont    None  None    None
# 1           1deg_jra55_ryf_rcp45cool_spinup500    None  None    None
# 2           1deg_jra55_ryf_rcp45warm_spinup500    None  None    None
# 3           1deg_jra55_ryf_rcp45cool_spinup400    None  None    None
# 4           1deg_jra55_ryf_rcp45warm_spinup400    None  None    None
# 5        1deg_jra55_ryf_rcp45cool_x2_spinup500    None  None    None
# 6        1deg_jra55_ryf_rcp45warm_x2_spinup500    None  None    None
# 7        1deg_jra55_ryf_rcp45warm_x1_spinup500    None  None    None
# 8        1deg_jra55_ryf_rcp45cool_x1_spinup500    None  None    None
# 9     1deg_jra55_ryf_warm_0sat_8dwlw_spinup500    None  None    None
# 10  1deg_jra55_ryf_warm_1.5sat_0dwlw_spinup500    None  None    None
# 11                   1deg_jra55_ryf_RCPwarm_x1    None  None    None
# 12                   1deg_jra55_ryf_RCPwarm_x2    None  None    None
# ...
