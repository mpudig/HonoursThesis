# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=8)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:45699' processes=8 threads=8, memory=90.00 GiB>

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'

session = cc.database.create_session(db)

# %%
help(cc.database.build_index)
# Out:
# Help on function build_index in module cosima_cookbook.database:
#
# build_index(directories, session, client=None, prune='delete', force=False, followsymlinks=False)
#     Index all netcdf files contained within experiment directories.
#
#     Requires a session for the database that's been created with the
#     create_session() function. If client is not None, use a distributed
#     client for processing files in parallel. If prune is set to 'flag' files
#     that are already in the database but are missing from the filesystem will
#     be flagged as missing, or if set to 'delete' they will be removed from the
#     database. If force is False only files that are not in the database will
#     be indexed, othewise if True all files will be indexed and their database
#     entries updated. Symbolically linked files and/or directories will be
#     indexed if followsymlinks is True.
#
#     Returns the number of new files that were indexed.

# %%
name = '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x1'

cc.database.build_index(name, session, force=True)
cc.querying.get_experiments(session, all=True)
# Out:
# Indexing experiment: 1deg_jra55_ryf_RCPcool_humid_x1
# 100%|██████████| 3820/3820 [06:29<00:00,  9.80it/s]
#                                     experiment contact email created  \
# 0                          1deg_jra55_ryf_cont    None  None    None
# 1        1deg_jra55_ryf_rcp45warm_x1_spinup500    None  None    None
# 2        1deg_jra55_ryf_rcp45cool_x1_spinup500    None  None    None
# 3     1deg_jra55_ryf_warm_0sat_8dwlw_spinup500    None  None    None
# 4   1deg_jra55_ryf_warm_1.5sat_0dwlw_spinup500    None  None    None
# 5              1deg_jra55_ryf_RCPwarm_humid_x1    None  None    None
# 6              1deg_jra55_ryf_RCPwarm_humid_x2    None  None    None
# 7              1deg_jra55_ryf_RCPcool_humid_x1    None  None    None
# 8              1deg_jra55_ryf_RCPcool_humid_x2    None  None    None
# 9               1deg_jra55_ryf_wcwc_step_test1    None  None    None
# 10              1deg_jra55_ryf_wcwc_step_test2    None  None    None
# 11          1deg_jra55_ryf_sinusoid_x1_period2    None  None    None
# 12          1deg_jra55_ryf_sinusoid_x1_period5    None  None    None
# 13         1deg_jra55_ryf_sinusoid_x1_period20    None  None    None
# 14         1deg_jra55_ryf_sinusoid_x1_period10    None  None    None
# 15          1deg_jra55_ryf_sinusoid_x1_period7    None  None    None
# 16         1deg_jra55_ryf_sinusoid_x1_period12    None  None    None
# 17         1deg_jra55_ryf_sinusoid_x1_period16    None  None    None
#
#    description notes   url                                           root_dir  \
# 0         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 1         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 2         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 3         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 4         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 5         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 6         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 7         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 8         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 9         None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 10        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 11        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 12        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 13        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 14        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 15        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 16        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
# 17        None  None  None  /scratch/e14/mp2135/access-om2/archive/1deg_jr...
#
#     ncfiles
# 0     24764
# 1     42426
# 2     42426
# 3     21206
# 4     21206
# 5     42426
# 6     42207
# 7      3820
# 8      4010
# 9      2108
# 10     4230
# 11    44968
# 12    44790
# 13    44968
# 14    44968
# 15     2626
# 16     2626
# 17     2626
