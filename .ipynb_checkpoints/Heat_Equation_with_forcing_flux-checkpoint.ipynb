# %%
import numpy as np
import scipy.integrate
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import TwoSlopeNorm
import cmocean as cm

# %% [markdown]
# ## The Equation
#
# Consider the following heat equation:
#
# $$
# \frac{\partial T}{\partial t} = \frac{\partial}{\partial z} \bigg(\kappa \frac{\partial T}{\partial z}\bigg) - w \frac{\partial T}{\partial z}+ \bigg(\frac{Q}{\rho_0 c_p z_{\text{mix}}} - \gamma(T - T_0) \bigg) \times H(z_{\text{mix}}-z) + \text{C.A.}$$
#
# where $T$ is the temperature, $\kappa$ is the *constant* (for the moment!) diffusivity, $Q$ is the prescribed surface heat flux, $\rho_0 = 1025$ kg m$^{-3}$ is the reference density, $c_p = 4000$ J/(kg C) is the specific heat capacity, $z_{\text{mix}}$ is the depth of the *mixing* layer (i.e., a minimum mixed layer), $\gamma$ is a damping term which acts to restore the surface back to $T_0$, the equilibrium temperature (like a climate feedback parameter). Finally $H$ represents a Heaviside function.
#
# We will write a forward-time, central-space finite difference scheme for this equation.

# %%
# Constants, data, parameters...

rho = 1025 # kg/m^3
c = 4000 # J/(kg C)
T_top = 22 # Top temperature
T_bot = 6 # Bottom temperature

dt = 10.0 * 86400 # units: s
dz = 5 # units: m
kappa = 1e-5 # units: m^2/s
w = 1e-7 # units: m/s
gamma = 1/(365 * 3 * 86400)
mu = 1/(365 * 2 * 86400)

z_mix = 30.0
z_b = 1000

# %%
### Intermediate functions

def convective_adjustment(T):
    
    # These loops simplify the hidden code in the cell below which is shit but works and is also easier to understand in my head
    
    def mixing_Rahmstorf(T):
        
        for i in range(len(T) - 1):
            
            if T[i] < T[i + 1]:
                
                j = 0
                
                # This loop mixes the instability downwards
                
                while T[i + j] < T[i + j + 1]:
                    
                    T[i : i + j + 2] = np.mean(T[i : i + j + 2])
                    
                    j += 1
                    
                break
            
        return T
    
    
    # Run the Rahmstorf mixing algorithm until the instability has been eliminated from the water column (i.e., from the mixing layer) 
    
    for k in range(int(z_mix / dz)):
        
        mixing_Rahmstorf(T)
    
    return mixing_Rahmstorf(T)




def steady_state(z):
    p = w / (2 * kappa)
    q = np.sqrt(w**2 + 4 * kappa * gamma) / (2 * kappa)
    
    A = (T_bot - T_top) / ((p - q) * np.exp(-(p + q) * z_mix) - (p + q) * np.exp(-(p - q) * z_mix) \
                       - kappa / w * (p**2 - q**2) * (1 - np.exp(- w / kappa * (z_b - z_mix))) \
                       * (np.exp(-(p + q) * z_mix) - np.exp(-(p - q) * z_mix)))
    
    C = A * (p**2 - q**2) * kappa / w * (np.exp(-(p + q) * z_mix) - np.exp(-(p - q) * z_mix)) * np.exp(w / kappa * z_mix)
    
    if z > - z_mix:
        return T_top + A * ((p - q) * np.exp((p + q) * z) - (p + q) * np.exp((p - q) * z))
    
    else:
        return T_bot + C * (np.exp(w / kappa * z) - np.exp(- w / kappa * z_b))

# %%
# Get analytic steady-state
z = np.arange(-z_b, 0, dz) # z positive upwards used to generate steady state
vss = np.vectorize(steady_state)
T_i = vss(z)[::-1] # Initial condition is the analytically determinated steady state

z = np.arange(0, z_b + dz, dz) # Now use z positive downwards for depth

# %%
plt.figure(figsize=(12,12))
plt.plot(T_i, z[:-1])
plt.gca().invert_yaxis()

# %%
### Ocean heat content

def OHC(T):
    
    return rho * c * np.cumsum(T)[-1] * dz
    #return np.mean(T)



def OHC_time(T_time):
    
    OHC_time = np.empty(T_time.shape[1])
    
    for i in range(len(OHC_time)):
        
        OHC_time[i] = OHC(T_time[: , i])
        
    return OHC_time

# %%
### The forward in time, central in space scheme with restoring and flux boundary conditions


def model(dt, dz, kappa, gamma, z_mix, years, T_initial, Q):
    
    # Data
    
    forcing = Q / (c * rho * z_mix)
    days = dt / 86400 # Timestep in days
    thermocline_depth = 1000 # B ase of thermocline = 1000m
    M = int(thermocline_depth / dz) # Number of spatial steps
    N = int(years * 360 / days) # Number of timesteps in days (taking 1 year = 360 days)
    z = np.linspace(0.0, 1000, M + 1)
    t = np.linspace(0.0, years * 360, N + 1)
    Hmix = np.heaviside(z_mix - z, 1)
    
    # Temperature and flux matrices. Prescribe initial and boundary conditions
    
    T = np.zeros((M, N + 1))
    F = np.zeros((M + 1, N + 1))
    
    T[:, 0] = T_initial # Initial conditions
    #T[-1, :] = T_bot
    F[0, :] = 0 # No flux at surface
    F[- 1, :] = 0 # No flux at base
    
    ### NB: NEED A STEP THAT PRESERVES THE MINIMUM MIXING LAYER, WHILST ALSO PRESERVING HEAT
    
    for n in range(0, N):
        
        for m in range(1, M):
            
            F[m, n] = kappa / dz * (T[m - 1, n] - T[m, n])
            
        for m in range(0, M): # NB: Needs to go to M - 1 if setting the temperature at the base.
             
            T[m, n + 1] = T[m, n] + dt / dz * (F[m, n] - F[m + 1, n]) \
            + dt * (forcing[n] - gamma * (T[m, n] - T[m, 0])) * Hmix[m + 1] \
            - dt * mu * (T[m, n] - T[m, 0]) * np.heaviside(z - 500, 1)[m] 
            # NB: "+ w" since z is positive downwards, this is an upwelling velocity, implying that it would have been negative on the LHS

            
        #Convective adjustment step
    
        convective_adjustment(T[:, n + 1])
        
    return T, t

# %%
# Steady state from model

years = 300
days = dt / 86400
N = int(years * 360 / days)
t = np.linspace(0.0, years * 360, N + 1)

# Control

Q = np.ones(int(years * 360 / days) + 1) * 0
gamma_year = 4
gamma = 1/(gamma_year * 365 * 86400)
mu_year = 50
mu = 1/(mu_year * 365 * 86400)
T_surf = T_i[0] # Temperature relaxed back to. This is the surface temperature at the beginning of the experiment

control_expt = model(dt, dz, kappa, gamma, z_mix, years, T_i, Q)[0]
steady = control_expt[:, -1]

# %%
plt.figure(figsize=(11,11))

time_index = -1

# plt.plot(control_expt[:, 0], z[:-1], label='Control at beginning')
plt.plot(steady, z[:-1], label='Soi-disant steady')
plt.plot(control_expt[:, -1], z[:-1], label='Control at end')
plt.gca().invert_yaxis()
plt.legend()

# %%
# 'Run' the experiment
years = 100
days = dt / 86400
N = int(years * 360 / days)
t = np.linspace(0.0, years * 360, N + 1)

# Control

Q = np.ones(int(years * 360 / days) + 1) * 0
gamma_year = 3
gamma = 1/(gamma_year * 365 * 86400)
mu_year = 50
mu = 1/(365 * mu_year * 86400)
T_surf = steady[0] # Temperature relaxed back to. This is the surface temperature at the beginning of the experiment

control_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, Q)[0]

# # Constant perturbation

Q = np.ones(int(years * 360 / days) + 1) * 8
cool_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, - Q)[0]
warm_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, Q)[0]

# %%
plt.figure(figsize=(11,11))

time_index = -1

plt.plot(cool_expt[:, 0], z[:-1], label='Cool at beginning')
plt.plot(cool_expt[:, 10], z[:-1], label='Cool at end')

plt.gca().invert_yaxis()
plt.legend()

# %%
plt.figure(figsize=(11,11))

time_index = -1

plt.plot(cool_expt[:, time_index], z[:-1], label='Cool at end')
plt.plot(warm_expt[:, time_index], z[:-1], label='Warm at end')
plt.plot(control_expt[:, time_index], z[:-1], label='Control at beginning')
# plt.plot(control_expt[:, -1], z[:-1], label='Control at end')
plt.gca().invert_yaxis()
plt.legend()

# %%
# Plot

days = dt / 86400
timesteps = cool_expt.shape[1]
length = (timesteps - 1) * days/365 
time_years = np.linspace(0,length,timesteps)

#Calculate ocean heat content
OHC_control = OHC_time(control_expt)
OHC_cool = OHC_time(cool_expt)
OHC_warm = OHC_time(warm_expt)

# Ocean heat content over time
plt.figure(figsize=(16,11))
plt.plot(time_years, -1 * (OHC_cool - OHC_control), label='cwcw')
plt.plot(time_years, OHC_warm - OHC_control, label='wcwc')
#plt.plot(np.linspace(0,length,timesteps), OHC_time(control_expt), label='control')

plt.grid()
plt.title('OHC, $\kappa$ = {} m$^2$/s, Q = {} W/m$^2$, $1/\gamma$ = {} yr'.format(kappa, Q[0], gamma_year), fontsize = 18)
plt.ylabel('OHC anomaly (J m$^{-2}$)', fontsize = 14)
plt.xlabel('Years', fontsize = 14)
plt.legend(fontsize=14)
#plt.savefig('OHC, kappa = {}, Q = {}.jpg'.format(kappa, Q))

# SST over time
plt.figure(figsize=(16,11))
plt.plot(time_years,  -1 * (cool_expt[0, :] - control_expt[0, :]), label='Cooling')
plt.plot(time_years, warm_expt[0, :] - control_expt[0, :], label='Warming')
#plt.plot(np.linspace(0, length, timesteps), control_expt[0, :], label='Control')

plt.grid()
plt.title('SST, $\kappa$ = {} m$^2$/s, Q = {} W/m$^2$, $1/\gamma$ = {} yr'.format(kappa, Q[0], gamma_year), fontsize = 18)
plt.ylabel('SST anomaly (K)', fontsize = 14)
plt.xlabel('Years',fontsize = 14)
plt.legend()
#plt.savefig('SST and GAT anomalies, single abrupt, kappa = {}, Q = {}, gamma = {}.jpg'.format(kappa, Q, gamma_year))

# %%
# #Animate the forcing

# fig = plt.figure(figsize=(18,11))
# ax = plt.axes(xlim=(4, 25), ylim=(z[0], z[-1]))

# line, = plt.plot([], [])

# def init():
#     line.set_data([], [])
#     return line,

# def animate(i):
#     line.set_data(warm_expt[:, i], z[1 : ])
#     return line,

# anim = animation.FuncAnimation(fig, animate, init_func=init,
#                                frames=len(warm_expt[0, :]), interval=50, blit=True)

# title = 'Temperature over depth, cooling'

# ax.set_title(title, fontsize = 18)
# ax.set_xlabel('Temperature (deg C)', fontsize = 15)
# ax.set_ylabel('Depth (m)', fontsize = 15)
# ax.invert_yaxis()

# anim.save('Warming.mp4')
# #plt.show()

# %% [markdown]
# ## Oscillatory forcing

# %%
period_yr = 10 # units: /year
period = period_yr * 360

def step(amp, period):
    period_day = period * 365
    return amp * np.sign(np.sin((np.pi / period_day) * t))

# %%
# Oscilatory perturbation

# 'Run' the experiment
years = 300
days = dt / 86400
N = int(years * 360 / days)
t = np.linspace(0.0, years * 360, N + 1)

# Control

Q = np.ones(int(years * 360 / days) + 1) * 0
gamma_year = 2
gamma = 1/(gamma_year * 365 * 86400)
mu_year = 100
mu = 1/(365 * mu_year * 86400)
T_surf = T_i[0] # Temperature relaxed back to. This is the surface temperature at the beginning of the experiment

control_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, Q)[0]

A = 9
P = 10
cw_forcing = step(- A, P)
wc_forcing = step(A, P)

cw_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, cw_forcing)[0]
wc_expt = model(dt, dz, kappa, gamma, z_mix, years, steady, wc_forcing)[0]

# %%
plt.figure(figsize=(11,11))

time_index = -1

plt.plot(cw_expt[:, time_index], z[:-1], label='cwcw at end')
plt.plot(wc_expt[:, time_index], z[:-1], label='wcwc at end')
plt.plot(control_expt[:, time_index], z[:-1], label='Control at end')

plt.gca().invert_yaxis()
plt.legend()

# %%
# Ocean heat content over time

days = dt / 86400
timesteps = cw_expt.shape[1]
length = (timesteps - 1) * days/365
time_years = np.linspace(0,length,timesteps)

#Calculate ocean heat content
OHC_control = OHC_time(control_expt)
OHC_cw = OHC_time(cw_expt)
OHC_wc = OHC_time(wc_expt)

#Plot
plt.figure(figsize=(16,11))
plt.plot(time_years, 1 * (OHC_cw - OHC_control), label='cwcw')
plt.plot(time_years, OHC_wc - OHC_control, label='wcwc')
#plt.plot(np.linspace(0,length,timesteps), OHC_time(control_expt), label='control')
plt.grid()
plt.title('OHC, $\kappa$ = {} m$^2$/s, Q = {} W/m$^2$, $1/\gamma$ = {} yr'.format(kappa, Q[0], gamma_year), fontsize = 18)
plt.ylabel('OHC anomaly (J m$^{-2}$)', fontsize = 14)
plt.xlabel('Years', fontsize = 14)
plt.legend(fontsize=14)
#plt.savefig('OHC, kappa = {}, Q = {}.jpg'.format(kappa, Q))

# SST over time
plt.figure(figsize=(16,11))
plt.plot(time_years,  -1 * (cw_expt[0, :] - control_expt[0, :]), label='cwcw')
plt.plot(time_years, wc_expt[0, :] - control_expt[0, :], label='wcwc')
#plt.plot(np.linspace(0, length, timesteps), control_expt[0, :], label='Control')

plt.grid()
plt.title('SST, $\kappa$ = {} m$^2$/s, Q = {} W/m$^2$, $1/\gamma$ = {} yr'.format(kappa, Q[0], gamma_year), fontsize = 18)
plt.ylabel('SST anomaly (K)', fontsize = 14)
plt.xlabel('Years',fontsize = 14)
plt.legend()
#plt.savefig('SST and GAT anomalies, single abrupt, kappa = {}, Q = {}, gamma = {}.jpg'.format(kappa, Q, gamma_year))

# %%
### Hovmoller plot

tt, zz = np.meshgrid(time_years, z[:-1])
cw_expt_anom = cw_expt - control_expt
wc_expt_anom = wc_expt - control_expt

cmap = cm.cm.balance
Tmin = np.min(cw_expt_anom)
Tmax = np.max(cw_expt_anom)

plt.figure(figsize=(19,13))
plt.contourf(tt, zz, cw_expt_anom, levels=51, cmap=cmap, norm=TwoSlopeNorm(0))
plt.colorbar().set_label(label='Temperature anomaly (deg C)', size=16)
plt.title('Hovmoller plot, cwcw experiment, anomaly', fontsize = 18)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Depth (m)', fontsize = 15)
plt.gca().invert_yaxis()

plt.figure(figsize=(19,13))
plt.contourf(tt, zz, wc_expt_anom, levels=51, cmap=cmap, norm=TwoSlopeNorm(0))
plt.colorbar().set_label(label='Temperature anomaly (deg C)', size=16)
plt.title('Hovmoller plot, wcwc experiment, anomaly', fontsize = 18)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Depth (m)', fontsize = 15)
plt.gca().invert_yaxis()

plt.figure(figsize=(19,13))
control_anom = control_expt - control_expt[:, 0][..., np.newaxis]
Tmin = np.min(control_anom)
Tmax = np.max(control_anom)
plt.contourf(tt, zz, control_anom, levels=51, cmap=cmap, norm=TwoSlopeNorm(0))
plt.colorbar().set_label(label='Temperature anomaly (deg C)', size=16)
plt.title('Hovmoller plot, wcwc experiment, anomaly', fontsize = 18)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Depth (m)', fontsize = 15)
plt.gca().invert_yaxis()

# %%
#Animate the forcing

wc_expt_animate = wc_expt[:, :3601]

fig = plt.figure(figsize=(18,11))
ax = plt.axes(xlim=(4, 25), ylim=(z[0], z[-1]))

line, = plt.plot([], [])

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(wc_expt_animate[:, i], z[1 : ])
    return line,

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=len(wc_expt_animate[0, :3601]), interval=50, blit=True)

title = 'Temperature over depth'

ax.set_title(title, fontsize = 18)
ax.set_xlabel('Temperature (deg C)', fontsize = 15)
ax.set_ylabel('Depth (m)', fontsize = 15)
ax.invert_yaxis()

anim.save('wcwc.mp4')
#plt.show()
