# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=8)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:46661' processes=8 threads=8, memory=128.85 GB>

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'

session = cc.database.create_session(db)

# directories = [cc.querying.get_experiments(session, all=True)['root_dir'][i] for i in range(len(cc.querying.get_experiments(session, all=True)['root_dir']))]
# directories = np.array(directories)[[9,10]].tolist()

directories = ['/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_sinusoid_x1_period2',
               '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_sinusoid_x1_period10',
               '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_sinusoid_x1_period5',
               '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_sinusoid_x1_period20']

# %%
cc.database.build_index('/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_cont', session, update=True)
cc.querying.get_experiments(session, all=True)
# Out:
# Indexing experiment: 1deg_jra55_ryf_cont
# 100%|██████████| 3902/3902 [06:50<00:00,  9.51it/s]
#                                     experiment contact email created  \
# 0                          1deg_jra55_ryf_cont    None  None    None
# 1        1deg_jra55_ryf_rcp45warm_x1_spinup500    None  None    None
# 2        1deg_jra55_ryf_rcp45cool_x1_spinup500    None  None    None
# 3     1deg_jra55_ryf_warm_0sat_8dwlw_spinup500    None  None    None
# 4   1deg_jra55_ryf_warm_1.5sat_0dwlw_spinup500    None  None    None
# 5              1deg_jra55_ryf_RCPwarm_humid_x1    None  None    None
# 6              1deg_jra55_ryf_RCPwarm_humid_x2    None  None    None
# 7              1deg_jra55_ryf_RCPcool_humid_x1    None  None    None
# 8              1deg_jra55_ryf_RCPcool_humid_x2    None  None    None
# 9               1deg_jra55_ryf_wcwc_step_test1    None  None    None
# 10              1deg_jra55_ryf_wcwc_step_test2    None  None    None
# ...
