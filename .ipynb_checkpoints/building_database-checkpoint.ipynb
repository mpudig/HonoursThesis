# %%
import cosima_cookbook as cc
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cmocean as cm
from scipy.optimize import curve_fit

from dask.distributed import Client

# %matplotlib inline

# %%
client = Client(n_workers=8)
display(client)
# Out:
# <Client: 'tcp://127.0.0.1:44553' processes=8 threads=8, memory=128.85 GB>

# %%
### Generate new database

db = '/scratch/e14/mp2135/access-om2/archive/databases/1deg_jra55_ryf_experiments_abrupt_spinup500.db'

session = cc.database.create_session(db)

directories = ['/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPwarm_humid_x1',
              '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPwarm_humid_x2',
              '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x1',
              '/scratch/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x2']

cool_humid_x2_new = '/g/data/e14/mp2135/access-om2/archive/1deg_jra55_ryf_RCPcool_humid_x2'
cc.database.build_index(cool_humid_x2_new, session)
# Out:
# Indexing experiment: 1deg_jra55_ryf_RCPcool_humid_x2
# 100%|██████████| 42426/42426 [1:07:07<00:00, 10.53it/s]
# 42426

# %%
cc.querying.get_experiments(session)
# Out:
#                                     experiment  ncfiles
# 0                          1deg_jra55_ryf_cont   150429
# 1                                    output111     2096
# 2                                    output112     2096
# 3                                    output113     2096
# 4                                    output114     2096
# 5                                    output115     2096
# 6                                    output116     2096
# 7                                    output117     2096
# 8                                    output118     2096
# 9                                    output119     2096
# 10          1deg_jra55_ryf_rcp45cool_spinup500    42426
# 11          1deg_jra55_ryf_rcp45warm_spinup500    47726
# 12          1deg_jra55_ryf_rcp45cool_spinup400    21206
# 13          1deg_jra55_ryf_rcp45warm_spinup400    21206
# 14       1deg_jra55_ryf_rcp45cool_x2_spinup500    42426
# 15       1deg_jra55_ryf_rcp45warm_x2_spinup500    42426
# 16       1deg_jra55_ryf_rcp45warm_x1_spinup500    42426
# 17       1deg_jra55_ryf_rcp45cool_x1_spinup500    42426
# 18    1deg_jra55_ryf_warm_0sat_8dwlw_spinup500    21206
# 19  1deg_jra55_ryf_warm_1.5sat_0dwlw_spinup500    21206
# 20                   1deg_jra55_ryf_RCPwarm_x1     9534
# 21                   1deg_jra55_ryf_RCPwarm_x2     9534
# 22             1deg_jra55_ryf_RCPwarm_humid_x1    42426
# 23             1deg_jra55_ryf_RCPwarm_humid_x2    42207
# 24             1deg_jra55_ryf_RCPcool_humid_x1    42207
# 25             1deg_jra55_ryf_RCPcool_humid_x2    42426
# 26             1deg_jra55_ryf_RCPcool_humid_x2    42426

# %%
data = cc.querying.get_experiments(session)
data.drop(labels = 25, axis = 0)
# Out:
#                                     experiment  ncfiles
# 0                          1deg_jra55_ryf_cont   150429
# 1                                    output111     2096
# 2                                    output112     2096
# 3                                    output113     2096
# 4                                    output114     2096
# 5                                    output115     2096
# 6                                    output116     2096
# 7                                    output117     2096
# 8                                    output118     2096
# 9                                    output119     2096
# 10          1deg_jra55_ryf_rcp45cool_spinup500    42426
# 11          1deg_jra55_ryf_rcp45warm_spinup500    47726
# 12          1deg_jra55_ryf_rcp45cool_spinup400    21206
# 13          1deg_jra55_ryf_rcp45warm_spinup400    21206
# 14       1deg_jra55_ryf_rcp45cool_x2_spinup500    42426
# 15       1deg_jra55_ryf_rcp45warm_x2_spinup500    42426
# 16       1deg_jra55_ryf_rcp45warm_x1_spinup500    42426
# 17       1deg_jra55_ryf_rcp45cool_x1_spinup500    42426
# 18    1deg_jra55_ryf_warm_0sat_8dwlw_spinup500    21206
# 19  1deg_jra55_ryf_warm_1.5sat_0dwlw_spinup500    21206
# 20                   1deg_jra55_ryf_RCPwarm_x1     9534
# 21                   1deg_jra55_ryf_RCPwarm_x2     9534
# 22             1deg_jra55_ryf_RCPwarm_humid_x1    42426
# 23             1deg_jra55_ryf_RCPwarm_humid_x2    42207
# 24             1deg_jra55_ryf_RCPcool_humid_x1    42207
# 26             1deg_jra55_ryf_RCPcool_humid_x2    42426
